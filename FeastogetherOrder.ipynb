# %%
import requests
import json

# %%
BRAND = 'Siammore'
ACT = '0976658581'
PWD = '1qaz2wsx'
STORE_ID = 'S2212290059'

# %%
headers = {
    'authority': 'www.feastogether.com.tw',
    'accept': 'application/json',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'content-type': 'application/json',
    'origin': 'https://www.feastogether.com.tw',
    'referer': 'https://www.feastogether.com.tw/booking/%s/search' % BRAND,
    'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
}

json_data = {
    'act': ACT,
    'pwd': PWD,
}

login = requests.post('https://www.feastogether.com.tw/api/994f5388-d001-4ca4-a7b1-72750d4211cf/custSignIn',
                      headers = headers,
                      json=json_data)
print('login')
print(login)
# Out:
# login
# <Response [200]>

# %%
authorization = 'Bearer ' + json.loads(login.content)['result']['customerLoginResp']['token']
print(authorization)
# Out:
# Bearer 0eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2NvdW50IjoiMDk3NjY1ODU4MSIsImlhdCI6MTY3OTAzODUyMCwiZXhwIjoxNjc5MDYwMTIwfQ.Hqk9tyugkvGWyyrikEGWm8eeXiLXHrRg0BA3jXxvLHg-976658581

# %%
headers = {
    'authority': 'www.feastogether.com.tw',
    'accept': 'application/json',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'content-type': 'application/json',
    'origin': 'https://www.feastogether.com.tw',
    'referer': 'https://www.feastogether.com.tw/booking/%s' % BRAND,
    'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
}

json_data = {
    'brandEngName': BRAND,
}

BrandState = requests.post('https://www.feastogether.com.tw/api/booking/checkBrandState', headers=headers, json=json_data)

# %%
brandId = json.loads(BrandState.content)['result']['brandId']
print(brandId)
# Out:
# BR00005

# %%
headers = {
    'authority': 'www.feastogether.com.tw',
    'accept': 'application/json',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'content-type': 'application/json',
    'origin': 'https://www.feastogether.com.tw',
    'referer': 'https://www.feastogether.com.tw/booking/%s' % BRAND,
    'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
}

json_data = {
    'brandId': brandId,
}

BrandLobbyPara = requests.post('https://www.feastogether.com.tw/api/booking/getBrandLobbyParameter', headers=headers, json=json_data)

# %%
BrandLobbyParameter = json.loads(BrandLobbyPara.content)
print(BrandLobbyParameter)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-972de192fc87> in <module>
# ----> 1 BrandLobbyParameter = json.loads(BrandLobbyPara.content)['results']
#       2 print(BrandLobbyParameter)
#
# KeyError: 'results'

# %%
headers = {
    'authority': 'www.feastogether.com.tw',
    'accept': 'application/json',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'act': ACT,
    'authorization': authorization,
    'content-type': 'application/json',
    'origin': 'https://www.feastogether.com.tw',
    'referer': 'https://www.feastogether.com.tw/booking/%s/process' % BRAND,
    'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
}

json_data = {
    'storeId': 'S2212290041',
    'mealDate': '2023-03-26',
}

booking_para = requests.post('https://www.feastogether.com.tw/api/booking/getBookingParameter', headers=headers, json=json_data, cookies=login.cookies)

print('booking para')
print(booking_para)
print(json.loads(booking_para.content))
# Out:
# booking para
# <Response [200]>
# ...

# %%
headers = {
    'authority': 'www.feastogether.com.tw',
    'accept': 'application/json',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'act': ACT,
    'authorization': authorization,
    # Already added when you pass json=
    # 'content-type': 'application/json',
    'origin': 'https://www.feastogether.com.tw',
    'referer': 'https://www.feastogether.com.tw/booking/%s/process' % BRAND,
    'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
}

json_data = {}

booking0 = requests.post('https://www.feastogether.com.tw/api/booking/b00king', headers=headers, json=json_data, cookies=booking_para.cookies)

print('booking0')
print(booking0)
print(json.loads(booking0.content))
# Out:
# booking0
# <Response [200]>
# {'statusCode': 1000, 'timestamp': '2023-03-17T07:03:48.318Z', 'message': '呼叫成功，未發生錯誤。', 'result': '98djk3jaoisiiliIliIlxch8ue'}

# %%
headers = {
    'authority': 'www.feastogether.com.tw',
    'accept': 'application/json',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
    'act': ACT,
    'authorization': authorization,
    'content-type': 'application/json',
    'origin': 'https://www.feastogether.com.tw',
    'referer': 'https://www.feastogether.com.tw/booking/%s/process' % BRAND,
    'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
}

json_data = {
    'storeId': 'S2212290041',
    'mealDate': '2023-03-26',
    'mealPurpose': '',
    'mealSeq': 4,
    'mealTime': '18:30',
    'mealPeriod': 'dinner',
    'special': 0,
    'childSeat': 0,
    'adult': 4,
    'child': 0,
    'chargeList': [
        {
            'seq': 201,
            'count': 4,
        },
        {
            'seq': 202,
            'count': 0,
        },
    ],
    'storeCode': 'TGBQ',
    'yuuO': json.loads(booking0.content)['result'],
    'redirectType': 'iEat_card',
    'domain': 'https://www.feastogether.com.tw',
    'pathFir': 'booking',
    'pathSec': 'result',
}

booking = requests.post('https://www.feastogether.com.tw/api/booking/booking', headers=headers, json=json_data, cookies=booking0.cookies)

print('booking')
print(booking)
print(json.loads(booking.content))
# Out:
# booking
# <Response [200]>
# {'statusCode': 1000, 'timestamp': '2023-03-17T07:04:02.465Z', 'message': '呼叫成功，未發生錯誤。', 'result': {'bookingId': '6ebaf513-f0e9-4cfc-8fed-d6a3738cf69f', 'brandName': '果然匯', 'storeName': '板橋店', 'mealDate': '2023/03/26', 'mealTime': '18:30', 'mealPeriod': '晚餐', 'bookingState': 'success', 'paymentState': 'payfree', 'expireTime': None}}
